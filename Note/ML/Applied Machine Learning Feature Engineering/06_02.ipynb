# %% [markdown]
# ## Build Models To Compare Features: Raw Original Features

# %% [markdown]
# ### Read In Data

# %%
# Read in data
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

train_features = pd.read_csv('./train_features_raw.csv')
train_labels = pd.read_csv('./train_labels.csv')

train_features.head()
# Out:
#    Pclass  Sex  Age_clean  SibSp  Parch     Fare  Cabin  Embarked
# 0       2    1       62.0      0      0  10.5000    147         2
# 1       3    1        8.0      4      1  29.1250    147         1
# 2       3    1       32.0      0      0  56.4958    147         2
# 3       3    0       20.0      1      0   9.8250    147         2
# 4       2    0       28.0      0      0  13.0000    147         2

# %%
# Generate correlation matrix heat map
matrix = np.triu(train_features.corr())
sns.heatmap(train_features.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GridSearchCV

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
# Conduct search for best params while running cross-validation (GridSearchCV)
rf = RandomForestClassifier()
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}

cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(train_features, train_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 512}
#
# 0.788 (+/-0.097) for {'max_depth': 2, 'n_estimators': 8}
# 0.798 (+/-0.108) for {'max_depth': 2, 'n_estimators': 16}
# 0.781 (+/-0.093) for {'max_depth': 2, 'n_estimators': 32}
# 0.8 (+/-0.1) for {'max_depth': 2, 'n_estimators': 64}
# 0.79 (+/-0.109) for {'max_depth': 2, 'n_estimators': 128}
# 0.794 (+/-0.114) for {'max_depth': 2, 'n_estimators': 256}
# 0.796 (+/-0.111) for {'max_depth': 2, 'n_estimators': 512}
# 0.805 (+/-0.101) for {'max_depth': 4, 'n_estimators': 8}
# 0.807 (+/-0.145) for {'max_depth': 4, 'n_estimators': 16}
# 0.828 (+/-0.088) for {'max_depth': 4, 'n_estimators': 32}
# 0.811 (+/-0.123) for {'max_depth': 4, 'n_estimators': 64}
# 0.813 (+/-0.095) for {'max_depth': 4, 'n_estimators': 128}
# 0.824 (+/-0.115) for {'max_depth': 4, 'n_estimators': 256}
# 0.817 (+/-0.118) for {'max_depth': 4, 'n_estimators': 512}
# 0.822 (+/-0.105) for {'max_depth': 8, 'n_estimators': 8}
# 0.835 (+/-0.077) for {'max_depth': 8, 'n_estimators': 16}
# 0.832 (+/-0.062) for {'max_depth': 8, 'n_estimators': 32}
# 0.837 (+/-0.051) for {'max_depth': 8, 'n_estimators': 64}
# 0.839 (+/-0.064) for {'max_depth': 8, 'n_estimators': 128}
# 0.841 (+/-0.063) for {'max_depth': 8, 'n_estimators': 256}
# 0.845 (+/-0.063) for {'max_depth': 8, 'n_estimators': 512}
# 0.822 (+/-0.045) for {'max_depth': 16, 'n_estimators': 8}
# 0.82 (+/-0.043) for {'max_depth': 16, 'n_estimators': 16}
# 0.82 (+/-0.042) for {'max_depth': 16, 'n_estimators': 32}
# 0.822 (+/-0.042) for {'max_depth': 16, 'n_estimators': 64}
# 0.826 (+/-0.06) for {'max_depth': 16, 'n_estimators': 128}
# 0.822 (+/-0.048) for {'max_depth': 16, 'n_estimators': 256}
# 0.824 (+/-0.048) for {'max_depth': 16, 'n_estimators': 512}
# 0.8 (+/-0.047) for {'max_depth': 32, 'n_estimators': 8}
# 0.824 (+/-0.077) for {'max_depth': 32, 'n_estimators': 16}
# 0.811 (+/-0.029) for {'max_depth': 32, 'n_estimators': 32}
# 0.824 (+/-0.031) for {'max_depth': 32, 'n_estimators': 64}
# 0.818 (+/-0.038) for {'max_depth': 32, 'n_estimators': 128}
# 0.824 (+/-0.054) for {'max_depth': 32, 'n_estimators': 256}
# 0.826 (+/-0.053) for {'max_depth': 32, 'n_estimators': 512}
# 0.816 (+/-0.01) for {'max_depth': None, 'n_estimators': 8}
# 0.815 (+/-0.032) for {'max_depth': None, 'n_estimators': 16}
# 0.82 (+/-0.072) for {'max_depth': None, 'n_estimators': 32}
# 0.832 (+/-0.042) for {'max_depth': None, 'n_estimators': 64}
# 0.822 (+/-0.045) for {'max_depth': None, 'n_estimators': 128}
# 0.826 (+/-0.055) for {'max_depth': None, 'n_estimators': 256}
# 0.822 (+/-0.049) for {'max_depth': None, 'n_estimators': 512}

# %% [markdown]
# ### Feature Importance

# %%
# Generate feature importance plot
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [train_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# ### Write Out Pickled Model

# %%
# Write out the model fit on the whole training set
joblib.dump(cv.best_estimator_, './mdl_raw_original_features.pkl')
# Out:
# ['./mdl_raw_original_features.pkl']
