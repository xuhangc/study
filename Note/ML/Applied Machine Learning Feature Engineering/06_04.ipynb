# %% [markdown]
# ## Build Models To Compare Features: All Features

# %% [markdown]
# ### Read In Data

# %%
# Read in data
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

train_features = pd.read_csv('./train_features_all.csv')
train_labels = pd.read_csv('./train_labels.csv')

train_features.head()
# Out:
#    Pclass  Sex  Age_clean  SibSp  Parch  Fare_clean  Fare_clean_tr  Cabin  \
# 0       2    1       62.0      0      0     10.5000       1.600434    147
# 1       3    1        8.0      4      1     29.1250       1.962697    147
# 2       3    1       32.0      0      0     56.4958       2.240801    147
# 3       3    0       20.0      1      0      9.8250       1.579307    147
# 4       2    0       28.0      0      0     13.0000       1.670278    147
#
#    Cabin_ind  Embarked_clean  Title  Family_cnt
# 0          0               3     11           0
# 1          0               2      7           5
# 2          0               3     11           0
# 3          0               3      8           1
# 4          0               3      8           0

# %%
# Generate correlation matrix heat map
matrix = np.triu(train_features.corr())
sns.heatmap(train_features.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GridSearchCV

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
# Conduct search for best params while running cross-validation (GridSearchCV)
rf = RandomForestClassifier()
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}
cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(train_features, train_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 64}
#
# 0.772 (+/-0.116) for {'max_depth': 2, 'n_estimators': 8}
# 0.79 (+/-0.105) for {'max_depth': 2, 'n_estimators': 16}
# 0.789 (+/-0.112) for {'max_depth': 2, 'n_estimators': 32}
# 0.781 (+/-0.121) for {'max_depth': 2, 'n_estimators': 64}
# 0.788 (+/-0.092) for {'max_depth': 2, 'n_estimators': 128}
# 0.794 (+/-0.095) for {'max_depth': 2, 'n_estimators': 256}
# 0.781 (+/-0.109) for {'max_depth': 2, 'n_estimators': 512}
# 0.818 (+/-0.075) for {'max_depth': 4, 'n_estimators': 8}
# 0.807 (+/-0.086) for {'max_depth': 4, 'n_estimators': 16}
# 0.822 (+/-0.074) for {'max_depth': 4, 'n_estimators': 32}
# 0.82 (+/-0.098) for {'max_depth': 4, 'n_estimators': 64}
# 0.822 (+/-0.087) for {'max_depth': 4, 'n_estimators': 128}
# 0.818 (+/-0.093) for {'max_depth': 4, 'n_estimators': 256}
# 0.82 (+/-0.105) for {'max_depth': 4, 'n_estimators': 512}
# 0.83 (+/-0.043) for {'max_depth': 8, 'n_estimators': 8}
# 0.824 (+/-0.066) for {'max_depth': 8, 'n_estimators': 16}
# 0.828 (+/-0.055) for {'max_depth': 8, 'n_estimators': 32}
# 0.833 (+/-0.059) for {'max_depth': 8, 'n_estimators': 64}
# 0.833 (+/-0.061) for {'max_depth': 8, 'n_estimators': 128}
# 0.833 (+/-0.044) for {'max_depth': 8, 'n_estimators': 256}
# 0.832 (+/-0.055) for {'max_depth': 8, 'n_estimators': 512}
# 0.813 (+/-0.072) for {'max_depth': 16, 'n_estimators': 8}
# 0.813 (+/-0.062) for {'max_depth': 16, 'n_estimators': 16}
# 0.807 (+/-0.032) for {'max_depth': 16, 'n_estimators': 32}
# 0.811 (+/-0.027) for {'max_depth': 16, 'n_estimators': 64}
# 0.813 (+/-0.038) for {'max_depth': 16, 'n_estimators': 128}
# 0.813 (+/-0.043) for {'max_depth': 16, 'n_estimators': 256}
# 0.811 (+/-0.068) for {'max_depth': 16, 'n_estimators': 512}
# 0.818 (+/-0.04) for {'max_depth': 32, 'n_estimators': 8}
# 0.813 (+/-0.052) for {'max_depth': 32, 'n_estimators': 16}
# 0.811 (+/-0.037) for {'max_depth': 32, 'n_estimators': 32}
# 0.811 (+/-0.05) for {'max_depth': 32, 'n_estimators': 64}
# 0.809 (+/-0.055) for {'max_depth': 32, 'n_estimators': 128}
# 0.807 (+/-0.049) for {'max_depth': 32, 'n_estimators': 256}
# 0.815 (+/-0.066) for {'max_depth': 32, 'n_estimators': 512}
# 0.811 (+/-0.074) for {'max_depth': None, 'n_estimators': 8}
# 0.815 (+/-0.05) for {'max_depth': None, 'n_estimators': 16}
# 0.811 (+/-0.054) for {'max_depth': None, 'n_estimators': 32}
# 0.811 (+/-0.046) for {'max_depth': None, 'n_estimators': 64}
# 0.809 (+/-0.055) for {'max_depth': None, 'n_estimators': 128}
# 0.809 (+/-0.044) for {'max_depth': None, 'n_estimators': 256}
# 0.815 (+/-0.054) for {'max_depth': None, 'n_estimators': 512}

# %% [markdown]
# ### Feature Importance

# %%
# Generate feature importance plot
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [train_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# ### Write Out Pickled Model

# %%
# Write out the model fit on the whole training set
joblib.dump(cv.best_estimator_, './mdl_all_features.pkl')
# Out:
# ['./mdl_all_features.pkl']
