# %% [markdown]
# ## Build Models To Compare Features: Reduced Set Of Features

# %% [markdown]
# ### Read In Data

# %%
# Read in data
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

train_features = pd.read_csv('./train_features_reduced.csv')
train_labels = pd.read_csv('./train_labels.csv')

train_features.head()
# Out:
#    Pclass  Sex  Age_clean  Family_cnt  Fare_clean_tr  Cabin_ind  Title
# 0       2    1       62.0           0       1.600434          0     11
# 1       3    1        8.0           5       1.962697          0      7
# 2       3    1       32.0           0       2.240801          0     11
# 3       3    0       20.0           1       1.579307          0      8
# 4       2    0       28.0           0       1.670278          0      8

# %%
# Generate correlation matrix heat map
matrix = np.triu(train_features.corr())
sns.heatmap(train_features.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GridSearchCV

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
# Conduct search for best params while running cross-validation (GridSearchCV)
rf = RandomForestClassifier()
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}
cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(train_features, train_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 8}
#
# 0.789 (+/-0.13) for {'max_depth': 2, 'n_estimators': 8}
# 0.775 (+/-0.136) for {'max_depth': 2, 'n_estimators': 16}
# 0.794 (+/-0.097) for {'max_depth': 2, 'n_estimators': 32}
# 0.796 (+/-0.132) for {'max_depth': 2, 'n_estimators': 64}
# 0.79 (+/-0.109) for {'max_depth': 2, 'n_estimators': 128}
# 0.789 (+/-0.12) for {'max_depth': 2, 'n_estimators': 256}
# 0.79 (+/-0.118) for {'max_depth': 2, 'n_estimators': 512}
# 0.818 (+/-0.085) for {'max_depth': 4, 'n_estimators': 8}
# 0.82 (+/-0.106) for {'max_depth': 4, 'n_estimators': 16}
# 0.815 (+/-0.104) for {'max_depth': 4, 'n_estimators': 32}
# 0.82 (+/-0.097) for {'max_depth': 4, 'n_estimators': 64}
# 0.82 (+/-0.088) for {'max_depth': 4, 'n_estimators': 128}
# 0.818 (+/-0.1) for {'max_depth': 4, 'n_estimators': 256}
# 0.817 (+/-0.105) for {'max_depth': 4, 'n_estimators': 512}
# 0.822 (+/-0.064) for {'max_depth': 8, 'n_estimators': 8}
# 0.813 (+/-0.078) for {'max_depth': 8, 'n_estimators': 16}
# 0.809 (+/-0.063) for {'max_depth': 8, 'n_estimators': 32}
# 0.815 (+/-0.076) for {'max_depth': 8, 'n_estimators': 64}
# 0.815 (+/-0.059) for {'max_depth': 8, 'n_estimators': 128}
# 0.818 (+/-0.077) for {'max_depth': 8, 'n_estimators': 256}
# 0.815 (+/-0.067) for {'max_depth': 8, 'n_estimators': 512}
# 0.794 (+/-0.064) for {'max_depth': 16, 'n_estimators': 8}
# 0.803 (+/-0.041) for {'max_depth': 16, 'n_estimators': 16}
# 0.809 (+/-0.038) for {'max_depth': 16, 'n_estimators': 32}
# 0.809 (+/-0.045) for {'max_depth': 16, 'n_estimators': 64}
# 0.803 (+/-0.051) for {'max_depth': 16, 'n_estimators': 128}
# 0.807 (+/-0.04) for {'max_depth': 16, 'n_estimators': 256}
# 0.803 (+/-0.042) for {'max_depth': 16, 'n_estimators': 512}
# 0.811 (+/-0.072) for {'max_depth': 32, 'n_estimators': 8}
# 0.803 (+/-0.082) for {'max_depth': 32, 'n_estimators': 16}
# 0.809 (+/-0.014) for {'max_depth': 32, 'n_estimators': 32}
# 0.803 (+/-0.035) for {'max_depth': 32, 'n_estimators': 64}
# 0.811 (+/-0.038) for {'max_depth': 32, 'n_estimators': 128}
# 0.813 (+/-0.039) for {'max_depth': 32, 'n_estimators': 256}
# 0.809 (+/-0.038) for {'max_depth': 32, 'n_estimators': 512}
# 0.802 (+/-0.027) for {'max_depth': None, 'n_estimators': 8}
# 0.809 (+/-0.031) for {'max_depth': None, 'n_estimators': 16}
# 0.811 (+/-0.029) for {'max_depth': None, 'n_estimators': 32}
# 0.813 (+/-0.035) for {'max_depth': None, 'n_estimators': 64}
# 0.807 (+/-0.051) for {'max_depth': None, 'n_estimators': 128}
# 0.805 (+/-0.046) for {'max_depth': None, 'n_estimators': 256}
# 0.805 (+/-0.036) for {'max_depth': None, 'n_estimators': 512}

# %% [markdown]
# ### Feature Importance

# %%
# Generate feature importance plot
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [train_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# ### Write Out Pickled Model

# %%
# Write out the model fit on the whole training set
joblib.dump(cv.best_estimator_, './mdl_reduced_features.pkl')
# Out:
# ['./mdl_reduced_features.pkl']
